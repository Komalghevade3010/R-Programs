# %% [markdown]
# <a href="https://colab.research.google.com/github/Komalghevade3010/R-Programs/blob/main/vaishnavi_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression

# %%
mobile=pd.read_csv("/content/Mobile Data.csv")
mobile.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
mobile.shape
# Out:
# (500, 21)

# %%
mobile.drop(["clock_speed","blue","n_cores","talk_time"],inplace=True,axis=1)

# %%
mobile.shape
# Out:
# (500, 17)

# %%
mobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  500 non-null    int64
#  1   dual_sim       500 non-null    int64
#  2   fc             500 non-null    int64
#  3   four_g         500 non-null    int64
#  4   int_memory     500 non-null    int64
#  5   m_dep          500 non-null    float64
#  6   mobile_wt      500 non-null    int64
#  7   pc             500 non-null    int64
#  8   px_height      500 non-null    int64
#  9   px_width       500 non-null    int64
#  10  ram            500 non-null    int64
#  11  sc_h           500 non-null    int64
#  12  sc_w           500 non-null    int64
#  13  three_g        500 non-null    int64
#  14  touch_screen   500 non-null    int64
#  15  wifi           500 non-null    int64
#  16  price_range    500 non-null    int64
# dtypes: float64(1), int64(16)
# ...

# %%
mobile=mobile.dropna()
mobile.shape
# Out:
# (500, 17)

# %%
mobile.head()
# Out:
#    battery_power  dual_sim  fc  four_g  int_memory  m_dep  mobile_wt  pc  \
# 0            842         0   1       0           7    0.6        188   2
# 1           1021         1   0       1          53    0.7        136   6
# 2            563         1   2       1          41    0.9        145   6
# 3            615         0   0       0          10    0.8        131   9
# 4           1821         0  13       1          44    0.6        141  14
#
#    px_height  px_width   ram  sc_h  sc_w  three_g  touch_screen  wifi  \
# 0         20       756  2549     9     7        0             0     1
# 1        905      1988  2631    17     3        1             1     0
# 2       1263      1716  2603    11     2        1             1     0
# 3       1216      1786  2769    16     8        1             0     0
# 4       1208      1212  1411     8     2        1             1     0
#
#    price_range
# 0            1
# 1            2
# 2            2
# 3            2
# 4            1

# %%
x=mobile.iloc[:,0:16]
y=mobile.iloc[:,16]

# %%
x
# Out:
#      battery_power  dual_sim  fc  four_g  int_memory  m_dep  mobile_wt  pc  \
# 0              842         0   1       0           7    0.6        188   2
# 1             1021         1   0       1          53    0.7        136   6
# 2              563         1   2       1          41    0.9        145   6
# 3              615         0   0       0          10    0.8        131   9
# 4             1821         0  13       1          44    0.6        141  14
# ..             ...       ...  ..     ...         ...    ...        ...  ..
# 495           1066         0   5       0          39    0.6        131  17
# 496           1554         1  11       0           5    1.0        124  12
# 497           1337         0  13       0          31    0.8        186  20
# 498           1926         1   1       1          33    0.4        172   2
# 499            869         1   3       0          34    0.1        104   4
#
# ...

# %%
y
# Out:
# 0      1
# 1      2
# 2      2
# 3      2
# 4      1
#       ..
# 495    2
# 496    3
# 497    1
# 498    2
# 499    3
# Name: price_range, Length: 500, dtype: int64

# %%
classifier=LogisticRegression()
classifier.fit(x,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=classifier.predict(x)

# %%
y_pred
# Out:
# array([2, 2, 2, 3, 1, 0, 3, 0, 0, 0, 3, 3, 1, 1, 0, 0, 2, 3, 2, 3, 3, 3,
#        1, 1, 3, 3, 3, 3, 3, 0, 3, 0, 2, 3, 0, 1, 1, 3, 3, 1, 2, 2, 2, 1,
#        1, 0, 3, 1, 0, 3, 1, 2, 3, 2, 2, 3, 0, 3, 1, 3, 1, 0, 0, 1, 3, 3,
#        3, 3, 0, 3, 3, 3, 0, 3, 0, 1, 0, 0, 3, 2, 3, 1, 2, 2, 1, 0, 0, 2,
#        2, 3, 2, 1, 2, 0, 0, 2, 1, 1, 1, 1, 2, 1, 1, 0, 1, 1, 2, 2, 3, 2,
#        2, 1, 0, 2, 3, 3, 3, 2, 0, 1, 1, 3, 3, 2, 1, 3, 3, 1, 3, 1, 3, 1,
#        2, 1, 3, 3, 2, 3, 0, 0, 1, 0, 3, 2, 0, 3, 1, 3, 1, 2, 2, 2, 0, 3,
#        0, 1, 0, 0, 2, 0, 3, 2, 0, 0, 3, 3, 1, 1, 2, 0, 3, 3, 2, 1, 3, 1,
#        1, 3, 2, 1, 1, 0, 1, 3, 3, 1, 3, 3, 1, 3, 2, 1, 3, 3, 2, 2, 2, 3,
#        3, 1, 0, 1, 0, 3, 2, 2, 2, 1, 3, 3, 3, 1, 0, 3, 1, 2, 0, 1, 1, 3,
#        0, 0, 3, 3, 2, 2, 3, 2, 2, 3, 3, 3, 1, 1, 3, 0, 0, 3, 1, 1, 3, 1,
#        3, 2, 3, 3, 0, 2, 2, 1, 2, 3, 1, 1, 0, 1, 0, 1, 0, 3, 0, 3, 0, 0,
#        2, 1, 3, 1, 3, 1, 0, 1, 3, 2, 2, 2, 3, 1, 0, 0, 3, 3, 0, 3, 2, 1,
# ...

# %%
y_pred_df=pd.DataFrame({'y':y,'Yhat':classifier.predict(x)})

# %%
y_pred_df
# Out:
#      y  Yhat
# 0    1     2
# 1    2     2
# 2    2     2
# 3    2     3
# 4    1     1
# ..  ..   ...
# 495  2     2
# 496  3     3
# 497  1     1
# 498  2     2
# 499  3     3
#
# [500 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix=confusion_matrix(y,y_pred)
print(confusion_matrix)
# Out:
# [[ 86  26   1   0]
#  [ 19  66  27  10]
#  [  0  32  51  41]
#  [  0   1  27 113]]

# %%
((86+66+51+113)/(86+26+1+0+19+66+27+10+0+32+51+41+0+1+27+113))*100
# Out:
# 63.2

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
fpr ,tpr,thresholds = roc_curve(y,classifier.predict_proba(x)[:,3],pos_label=3)

# %%
auc = roc_auc_score(y, classifier.predict_proba(x),multi_class='ovr')

# %%
import matplotlib.pyplot as plt
plt.plot(fpr, tpr, color='red')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
plt.ylabel('True Positive Rate')
plt.show()
